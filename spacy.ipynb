# %% [markdown]
# ## Daniel Joaquim Paulino
#
#
# ## TP1  using library : Spacy
#
# and Huggingface to Preprocess the following English and Arabic texts.

# %% [markdown]
# # Text to Tokenize in English

# %%
english_text=("""
            Perhaps one of the most significant advances made by Arabic mathematics began at this time 
            with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to 
            understand just how significant this new idea was. It was a revolutionary move away 
            from the Greek concept of mathematics which was essentially geometry. Algebra was a 
            unifying theory which allowed rational numbers, irrational numbers, geometrical 
            magnitudes,etc., to all be treated as "algebraic objects". It gave mathematics a whole new 
            development path so much broader in concept to that which had existed before, and provided a
            vehicle for future development of the subject. Another important aspect of the introduction 
            of algebraic ideas was that it allowed mathematics to be applied to itself in a way which 
            had not happened before.""")
print("#THIS IS OUR TEXT TO TOKENIZE IN ENGLISH :",English_text)
# Out:
# #THIS IS OUR TEXT TO TOKENIZE IN ENGLISH :
#             Perhaps one of the most significant advances made by Arabic mathematics began at this time
#             with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to
#             understand just how significant this new idea was. It was a revolutionary move away
#             from the Greek concept of mathematics which was essentially geometry. Algebra was a
#             unifying theory which allowed rational numbers, irrational numbers, geometrical
#             magnitudes,etc., to all be treated as "algebraic objects". It gave mathematics a whole new
#             development path so much broader in concept to that which had existed before, and provided a
#             vehicle for future development of the subject. Another important aspect of the introduction
#             of algebraic ideas was that it allowed mathematics to be applied to itself in a way which
#             had not happened before.

# %%
#IMPORT LIBRARY SPACY
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(english_text)

# %%
#This Tokenizetion read de lignes of texts

for token in doc: 
     print(token)
# Out:
#
# Perhaps
# one
# of
# the
# most
# significant
# advances
# made
# by
# Arabic
# mathematics
# began
# at
# this
# time
#
#
# with
# the
# work
# of
# al
# -
# Khwarizmi
# ,
# namely
# the
# beginnings
# of
# algebra
# .
# It
# is
# important
# to
#
#
# understand
# just
# how
# significant
# this
# new
# idea
# was
# .
# It
# was
# a
# revolutionary
# move
# away
#
#
# from
# the
# Greek
# concept
# of
# mathematics
# which
# was
# essentially
# geometry
# .
# Algebra
# was
# a
#
#
# unifying
# theory
# which
# allowed
# rational
# numbers
# ,
# irrational
# numbers
# ,
# geometrical
#
#
# magnitudes
# ,
# etc
# .
# ,
# to
# all
# be
# treated
# as
# "
# algebraic
# objects
# "
# .
# It
# gave
# mathematics
# a
# whole
# new
#
#
# development
# path
# so
# much
# broader
# in
# concept
# to
# that
# which
# had
# existed
# before
# ,
# and
# provided
# a
#
#
# vehicle
# for
# future
# development
# of
# the
# subject
# .
# Another
# important
# aspect
# of
# the
# introduction
#
#
# of
# algebraic
# ideas
# was
# that
# it
# allowed
# mathematics
# to
# be
# applied
# to
# itself
# in
# a
# way
# which
#
#
# had
# not
# happened
# before
# .

# %%
#This Tokenizetion read de lignes of texts and ¥qour POS tagging

for token in doc: 
     print(token.text,  token.pos_, token.tag_)
# Out:
#              SPACE _SP
# Perhaps ADV RB
# one NUM CD
# of ADP IN
# the DET DT
# most ADV RBS
# significant ADJ JJ
# advances NOUN NNS
# made VERB VBN
# by ADP IN
# Arabic ADJ JJ
# mathematics NOUN NNS
# began VERB VBD
# at ADP IN
# this DET DT
# time NOUN NN
#
#              SPACE _SP
# with ADP IN
# the DET DT
# work NOUN NN
# of ADP IN
# al PROPN NNP
# - PUNCT HYPH
# Khwarizmi PROPN NNP
# , PUNCT ,
# namely ADV RB
# the DET DT
# beginnings NOUN NNS
# of ADP IN
# algebra PROPN NNP
# . PUNCT .
# It PRON PRP
# is AUX VBZ
# important ADJ JJ
# to ADP IN
#
#              SPACE _SP
# understand VERB VBP
# just ADV RB
# how ADV WRB
# significant ADJ JJ
# this DET DT
# new ADJ JJ
# idea NOUN NN
# was AUX VBD
# . PUNCT .
# It PRON PRP
# was AUX VBD
# a DET DT
# revolutionary ADJ JJ
# move NOUN NN
# away ADV RB
#
#              SPACE _SP
# from ADP IN
# the DET DT
# Greek ADJ JJ
# concept NOUN NN
# of ADP IN
# mathematics NOUN NNS
# which DET WDT
# was VERB VBD
# essentially ADV RB
# geometry NOUN NN
# . PUNCT .
# Algebra PROPN NNP
# was AUX VBD
# a DET DT
#
#              SPACE _SP
# unifying NOUN NN
# theory NOUN NN
# which DET WDT
# allowed VERB VBD
# rational ADJ JJ
# numbers NOUN NNS
# , PUNCT ,
# irrational ADJ JJ
# numbers NOUN NNS
# , PUNCT ,
# geometrical ADJ JJ
#
#              SPACE _SP
# magnitudes NOUN NNS
# , PUNCT ,
# etc X FW
# . X FW
# , PUNCT ,
# to AUX IN
# all DET DT
# be AUX VB
# treated VERB VBN
# as ADP IN
# " PUNCT ``
# algebraic ADJ JJ
# objects NOUN NNS
# " PUNCT ''
# . PUNCT .
# It PRON PRP
# gave VERB VBD
# mathematics NOUN NNS
# a DET DT
# whole ADJ JJ
# new ADJ JJ
#
#              SPACE _SP
# development NOUN NN
# path NOUN NN
# so ADV RB
# much ADV RB
# broader ADJ JJR
# in ADP IN
# concept NOUN NN
# to ADP IN
# that DET DT
# which DET WDT
# had AUX VBD
# existed VERB VBN
# before ADV RB
# , PUNCT ,
# and CCONJ CC
# provided VERB VBD
# a DET DT
#
#              SPACE _SP
# vehicle NOUN NN
# for ADP IN
# future ADJ JJ
# development NOUN NN
# of ADP IN
# the DET DT
# subject NOUN NN
# . PUNCT .
# Another DET DT
# important ADJ JJ
# aspect NOUN NN
# of ADP IN
# the DET DT
# introduction NOUN NN
#
#              SPACE _SP
# of ADP IN
# algebraic ADJ JJ
# ideas NOUN NNS
# was AUX VBD
# that SCONJ IN
# it PRON PRP
# allowed VERB VBD
# mathematics NOUN NNS
# to PART TO
# be AUX VB
# applied VERB VBN
# to ADP IN
# itself PRON PRP
# in ADP IN
# a DET DT
# way NOUN NN
# which DET WDT
#
#              SPACE _SP
# had AUX VBD
# not PART RB
# happened VERB VBN
# before ADV RB
# . PUNCT .

# %%
#This Tokenition is for Lemmatization of  the lignes of texts and guive your pos tagging


for token in doc: 
     print(token, token.lemma_, token.pos_)
# Out:
#
#              SPACE
# Perhaps perhaps ADV
# one one NUM
# of of ADP
# the the DET
# most most ADV
# significant significant ADJ
# advances advance NOUN
# made make VERB
# by by ADP
# Arabic arabic ADJ
# mathematics mathematic NOUN
# began begin VERB
# at at ADP
# this this DET
# time time NOUN
#
#
#              SPACE
# with with ADP
# the the DET
# work work NOUN
# of of ADP
# al al PROPN
# - - PUNCT
# Khwarizmi Khwarizmi PROPN
# , , PUNCT
# namely namely ADV
# the the DET
# beginnings beginning NOUN
# of of ADP
# algebra algebra PROPN
# . . PUNCT
# It it PRON
# is be AUX
# important important ADJ
# to to ADP
#
#
#              SPACE
# understand understand VERB
# just just ADV
# how how ADV
# significant significant ADJ
# this this DET
# new new ADJ
# idea idea NOUN
# was be AUX
# . . PUNCT
# It it PRON
# was be AUX
# a a DET
# revolutionary revolutionary ADJ
# move move NOUN
# away away ADV
#
#
#              SPACE
# from from ADP
# the the DET
# Greek greek ADJ
# concept concept NOUN
# of of ADP
# mathematics mathematic NOUN
# which which DET
# was be VERB
# essentially essentially ADV
# geometry geometry NOUN
# . . PUNCT
# Algebra Algebra PROPN
# was be AUX
# a a DET
#
#
#              SPACE
# unifying unifying NOUN
# theory theory NOUN
# which which DET
# allowed allow VERB
# rational rational ADJ
# numbers number NOUN
# , , PUNCT
# irrational irrational ADJ
# numbers number NOUN
# , , PUNCT
# geometrical geometrical ADJ
#
#
#              SPACE
# magnitudes magnitude NOUN
# , , PUNCT
# etc etc X
# . . X
# , , PUNCT
# to to AUX
# all all DET
# be be AUX
# treated treat VERB
# as as ADP
# " " PUNCT
# algebraic algebraic ADJ
# objects object NOUN
# " " PUNCT
# . . PUNCT
# It it PRON
# gave give VERB
# mathematics mathematic NOUN
# a a DET
# whole whole ADJ
# new new ADJ
#
#
#              SPACE
# development development NOUN
# path path NOUN
# so so ADV
# much much ADV
# broader broad ADJ
# in in ADP
# concept concept NOUN
# to to ADP
# that that DET
# which which DET
# had have AUX
# existed exist VERB
# before before ADV
# , , PUNCT
# and and CCONJ
# provided provide VERB
# a a DET
#
#
#              SPACE
# vehicle vehicle NOUN
# for for ADP
# future future ADJ
# development development NOUN
# of of ADP
# the the DET
# subject subject NOUN
# . . PUNCT
# Another another DET
# important important ADJ
# aspect aspect NOUN
# of of ADP
# the the DET
# introduction introduction NOUN
#
#
#              SPACE
# of of ADP
# algebraic algebraic ADJ
# ideas idea NOUN
# was be AUX
# that that SCONJ
# it it PRON
# allowed allow VERB
# mathematics mathematic NOUN
# to to PART
# be be AUX
# applied apply VERB
# to to ADP
# itself itself PRON
# in in ADP
# a a DET
# way way NOUN
# which which DET
#
#
#              SPACE
# had have AUX
# not not PART
# happened happen VERB
# before before ADV
# . . PUNCT
