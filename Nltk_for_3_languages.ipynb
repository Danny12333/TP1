# %% [markdown]
# ## Daniel Joaquim Paulino
#
# ## TP1  using library :  NLTK
#
# Spacy and Huggingface to Preprocess the following English and Arabic texts.

# %% [markdown]
# # Tokenization

# %% [markdown]
# ### Text to Tokenize in English

# %%
  English_text=("""
            Perhaps one of the most significant advances made by Arabic mathematics began at this time 
            with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to 
            understand just how significant this new idea was. It was a revolutionary move away 
            from the Greek concept of mathematics which was essentially geometry. Algebra was a 
            unifying theory which allowed rational numbers, irrational numbers, geometrical 
            magnitudes,etc., to all be treated as "algebraic objects". It gave mathematics a whole new 
            development path so much broader in concept to that which had existed before, and provided a
            vehicle for future development of the subject. Another important aspect of the introduction 
            of algebraic ideas was that it allowed mathematics to be applied to itself in a way which 
            had not happened before.""")
print("#THIS IS OUR TEXT TO TOKENIZE IN ENGLISH :",English_text)
# Out:
# #THIS IS OUR TEXT TO TOKENIZE IN ENGLISH :
#           Perhaps one of the most significant advances made by Arabic mathematics began at this time
#           with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to
#           understand just how significant this new idea was. It was a revolutionary move away
#           from the Greek concept of mathematics which was essentially geometry. Algebra was a
#           unifying theory which allowed rational numbers, irrational numbers, geometrical
#           magnitudes,etc., to all be treated as "algebraic objects". It gave mathematics a whole new
#           development path so much broader in concept to that which had existed before, and provided a
#           vehicle for future development of the subject. Another important aspect of the introduction
#           of algebraic ideas was that it allowed mathematics to be applied to itself in a way which
#           had not happened before.

# %% [markdown]
# ### Download all packege

# %%
import nltk
#nltk.download('all')

# %% [markdown]
# # 1-  Word to Tokenize

# %% [markdown]
# ### Import de library NLTK

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Tokenize the text

# %%
resul_word_token = word_tokenize(English_text)

# %%
print("RESULT: ",resul_word_token)
# Out:
# RESULT:  ['Perhaps', 'one', 'of', 'the', 'most', 'significant', 'advances', 'made', 'by', 'Arabic', 'mathematics', 'began', 'at', 'this', 'time', 'with', 'the', 'work', 'of', 'al-Khwarizmi', ',', 'namely', 'the', 'beginnings', 'of', 'algebra', '.', 'It', 'is', 'important', 'to', 'understand', 'just', 'how', 'significant', 'this', 'new', 'idea', 'was', '.', 'It', 'was', 'a', 'revolutionary', 'move', 'away', 'from', 'the', 'Greek', 'concept', 'of', 'mathematics', 'which', 'was', 'essentially', 'geometry', '.', 'Algebra', 'was', 'a', 'unifying', 'theory', 'which', 'allowed', 'rational', 'numbers', ',', 'irrational', 'numbers', ',', 'geometrical', 'magnitudes', ',', 'etc.', ',', 'to', 'all', 'be', 'treated', 'as', '``', 'algebraic', 'objects', "''", '.', 'It', 'gave', 'mathematics', 'a', 'whole', 'new', 'development', 'path', 'so', 'much', 'broader', 'in', 'concept', 'to', 'that', 'which', 'had', 'existed', 'before', ',', 'and', 'provided', 'a', 'vehicle', 'for', 'future', 'development', 'of', 'the', 'subject', '.', 'Another', 'important', 'aspect', 'of', 'the', 'introduction', 'of', 'algebraic', 'ideas', 'was', 'that', 'it', 'allowed', 'mathematics', 'to', 'be', 'applied', 'to', 'itself', 'in', 'a', 'way', 'which', 'had', 'not', 'happened', 'before', '.']

# %% [markdown]
# ### Text to Tokenize in Arab

# %%
Arab_text =("""
ربما كانت أحد أھم التطورات التي قامت بھا الریاضیات العربیة التي
بدأت في ھذا الوقت بعمل الخوارزمي وھي بدایات الجبر، ومن المھم فھم كیف كانت ھذه الفكرة الجدیدة مھمة، فقد كانت خطوة ثوریة بعیدا عن المفھوم
الیوناني للریاضیات التي ھي في جوھرھا ھندسة، الجبر كان نظریة موحدة تتیح الأعداد الكسریة والأعداد اللا كسریة، والمقادیر الھندسیة وغیرھا،
أن تتعامل على أنھا أجسام جبریة، وأعطت الریاضیات ككل مسارا جدیدا للتطور بمفھوم أوسع بكثیر من الذي كان موجودا من قبل، وقدم وسیلة
للتنمیة في ھذا الموضوع مستقبلا. وجانب آخر مھم لإدخال أفكار الجبر وھو أنھ سمح بتطبیق الریاضیات على نفسھا بطریقة لم تحدث من قبل

""")

#print("#THIS IS OUR TEXT TO TOKENIZE IN ARAB:",Arab_text)

# %% [markdown]
# ### Tokenize the text

# %%
resul_word_token2 = word_tokenize(Arab_text)

# %%
print("RESULT: ",resul_word_token2)
# Out:
# RESULT:  ['ربما', 'كانت', 'أحد', 'أھم', 'التطورات', 'التي', 'قامت', 'بھا', 'الریاضیات', 'العربیة', 'التي', 'بدأت', 'في', 'ھذا', 'الوقت', 'بعمل', 'الخوارزمي', 'وھي', 'بدایات', 'الجبر،', 'ومن', 'المھم', 'فھم', 'كیف', 'كانت', 'ھذه', 'الفكرة', 'الجدیدة', 'مھمة،', 'فقد', 'كانت', 'خطوة', 'ثوریة', 'بعیدا', 'عن', 'المفھوم', 'الیوناني', 'للریاضیات', 'التي', 'ھي', 'في', 'جوھرھا', 'ھندسة،', 'الجبر', 'كان', 'نظریة', 'موحدة', 'تتیح', 'الأعداد', 'الكسریة', 'والأعداد', 'اللا', 'كسریة،', 'والمقادیر', 'الھندسیة', 'وغیرھا،', 'أن', 'تتعامل', 'على', 'أنھا', 'أجسام', 'جبریة،', 'وأعطت', 'الریاضیات', 'ككل', 'مسارا', 'جدیدا', 'للتطور', 'بمفھوم', 'أوسع', 'بكثیر', 'من', 'الذي', 'كان', 'موجودا', 'من', 'قبل،', 'وقدم', 'وسیلة', 'للتنمیة', 'في', 'ھذا', 'الموضوع', 'مستقبلا', '.', 'وجانب', 'آخر', 'مھم', 'لإدخال', 'أفكار', 'الجبر', 'وھو', 'أنھ', 'سمح', 'بتطبیق', 'الریاضیات', 'على', 'نفسھا', 'بطریقة', 'لم', 'تحدث', 'من', 'قبل']

# %% [markdown]
# ### Text to Tokenize in Portuguese

# %%
Portug_text=("""
        Talvez um dos avanços mais significativos do árabe tenha começado nessa época com o trabalho 
        de al-Khwarizmi, ou seja, o início da álgebra. É importante entender o quão significativa foi 
        essa nova ideia. Foi um afastamento revolucionário do conceito grego de matemática, que era 
        essencialmente geometria. A álgebra era uma teoria unificadora que permitia
        números, números irracionais, magnitudes geométricas, etc., todos devem ser tratados 
        como "objetos algébricos". Deu à matemática um caminho de desenvolvimento totalmente novo,
        muito mais amplo em conceito do que existia antes, e forneceu um veículo para o desenvolvimento 
        futuro do assunto. Outro aspecto importante da introdução das idéias algébricas foi que ela 
        permitiu que a matemática fosse aplicada a si mesma de uma forma que não havia acontecido antes.

""")

print("#THIS IS OUR TEXT TO TOKENIZE IN PORTUGUESE :",Portug_text)
# Out:
# #THIS IS OUR TEXT TO TOKENIZE IN PORTUGUESE :
#         Talvez um dos avanços mais significativos do árabe tenha começado nessa época com o trabalho
#         de al-Khwarizmi, ou seja, o início da álgebra. É importante entender o quão significativa foi
#         essa nova ideia. Foi um afastamento revolucionário do conceito grego de matemática, que era
#         essencialmente geometria. A álgebra era uma teoria unificadora que permitia
#         números, números irracionais, magnitudes geométricas, etc., todos devem ser tratados
#         como "objetos algébricos". Deu à matemática um caminho de desenvolvimento totalmente novo,
#         muito mais amplo em conceito do que existia antes, e forneceu um veículo para o desenvolvimento
#         futuro do assunto. Outro aspecto importante da introdução das idéias algébricas foi que ela
#         permitiu que a matemática fosse aplicada a si mesma de uma forma que não havia acontecido antes.

# %% [markdown]
# # Tokenize the text

# %%
resul_word_token3 = word_tokenize(Portug_text)

# %%
print("#RESULT: ",resul_word_token3)
# Out:
# #RESULT:  ['Talvez', 'um', 'dos', 'avanços', 'mais', 'significativos', 'do', 'árabe', 'tenha', 'começado', 'nessa', 'época', 'com', 'o', 'trabalho', 'de', 'al-Khwarizmi', ',', 'ou', 'seja', ',', 'o', 'início', 'da', 'álgebra', '.', 'É', 'importante', 'entender', 'o', 'quão', 'significativa', 'foi', 'essa', 'nova', 'ideia', '.', 'Foi', 'um', 'afastamento', 'revolucionário', 'do', 'conceito', 'grego', 'de', 'matemática', ',', 'que', 'era', 'essencialmente', 'geometria', '.', 'A', 'álgebra', 'era', 'uma', 'teoria', 'unificadora', 'que', 'permitia', 'números', ',', 'números', 'irracionais', ',', 'magnitudes', 'geométricas', ',', 'etc.', ',', 'todos', 'devem', 'ser', 'tratados', 'como', '``', 'objetos', 'algébricos', "''", '.', 'Deu', 'à', 'matemática', 'um', 'caminho', 'de', 'desenvolvimento', 'totalmente', 'novo', ',', 'muito', 'mais', 'amplo', 'em', 'conceito', 'do', 'que', 'existia', 'antes', ',', 'e', 'forneceu', 'um', 'veículo', 'para', 'o', 'desenvolvimento', 'futuro', 'do', 'assunto', '.', 'Outro', 'aspecto', 'importante', 'da', 'introdução', 'das', 'idéias', 'algébricas', 'foi', 'que', 'ela', 'permitiu', 'que', 'a', 'matemática', 'fosse', 'aplicada', 'a', 'si', 'mesma', 'de', 'uma', 'forma', 'que', 'não', 'havia', 'acontecido', 'antes', '.']

# %% [markdown]
# # 2 - Sentente Tokenization

# %%
#IMPORT THE LIBERARY


from nltk.tokenize import sent_tokenize

#TOKENIZE THE TEXT

result_sent_tokenise = sent_tokenize(English_text)

#PRINT THE RESULT OF SENTENCE TOKENIZETION 

print("#RESULT : ",result_sent_tokenise)
# Out:
# #RESULT :  ['\n          Perhaps one of the most significant advances made by Arabic mathematics began at this time \n          with the work of al-Khwarizmi, namely the beginnings of algebra.', 'It is important to \n          understand just how significant this new idea was.', 'It was a revolutionary move away \n          from the Greek concept of mathematics which was essentially geometry.', 'Algebra was a \n          unifying theory which allowed rational numbers, irrational numbers, geometrical \n          magnitudes,etc., to all be treated as "algebraic objects".', 'It gave mathematics a whole new \n          development path so much broader in concept to that which had existed before, and provided a\n          vehicle for future development of the subject.', 'Another important aspect of the introduction \n          of algebraic ideas was that it allowed mathematics to be applied to itself in a way which \n          had not happened before.']

# %% [markdown]
# # POS_tagging
#
# ### POS TAGGING FOR ENGLISH

# %%
#POS TAGGING FOR ENGLISH


post_tagEng = nltk.pos_tag(resul_word_token)

print("#RESULT OF POST TAG: ", post_tagEng)
# Out:
# #RESULT OF POST TAG:  [('Perhaps', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('significant', 'JJ'), ('advances', 'NNS'), ('made', 'VBN'), ('by', 'IN'), ('Arabic', 'NNP'), ('mathematics', 'NNS'), ('began', 'VBD'), ('at', 'IN'), ('this', 'DT'), ('time', 'NN'), ('with', 'IN'), ('the', 'DT'), ('work', 'NN'), ('of', 'IN'), ('al-Khwarizmi', 'JJ'), (',', ','), ('namely', 'RB'), ('the', 'DT'), ('beginnings', 'NNS'), ('of', 'IN'), ('algebra', 'NN'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('important', 'JJ'), ('to', 'TO'), ('understand', 'VB'), ('just', 'RB'), ('how', 'WRB'), ('significant', 'JJ'), ('this', 'DT'), ('new', 'JJ'), ('idea', 'NN'), ('was', 'VBD'), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('revolutionary', 'JJ'), ('move', 'NN'), ('away', 'RB'), ('from', 'IN'), ('the', 'DT'), ('Greek', 'NNP'), ('concept', 'NN'), ('of', 'IN'), ('mathematics', 'NNS'), ('which', 'WDT'), ('was', 'VBD'), ('essentially', 'RB'), ('geometry', 'JJ'), ('.', '.'), ('Algebra', 'NNP'), ('was', 'VBD'), ('a', 'DT'), ('unifying', 'JJ'), ('theory', 'NN'), ('which', 'WDT'), ('allowed', 'VBD'), ('rational', 'JJ'), ('numbers', 'NNS'), (',', ','), ('irrational', 'JJ'), ('numbers', 'NNS'), (',', ','), ('geometrical', 'JJ'), ('magnitudes', 'NNS'), (',', ','), ('etc.', 'NN'), (',', ','), ('to', 'TO'), ('all', 'DT'), ('be', 'VB'), ('treated', 'VBN'), ('as', 'IN'), ('``', '``'), ('algebraic', 'JJ'), ('objects', 'NNS'), ("''", "''"), ('.', '.'), ('It', 'PRP'), ('gave', 'VBD'), ('mathematics', 'NNS'), ('a', 'DT'), ('whole', 'JJ'), ('new', 'JJ'), ('development', 'NN'), ('path', 'NN'), ('so', 'RB'), ('much', 'JJ'), ('broader', 'JJR'), ('in', 'IN'), ('concept', 'NN'), ('to', 'TO'), ('that', 'DT'), ('which', 'WDT'), ('had', 'VBD'), ('existed', 'VBN'), ('before', 'IN'), (',', ','), ('and', 'CC'), ('provided', 'VBD'), ('a', 'DT'), ('vehicle', 'NN'), ('for', 'IN'), ('future', 'JJ'), ('development', 'NN'), ('of', 'IN'), ('the', 'DT'), ('subject', 'NN'), ('.', '.'), ('Another', 'DT'), ('important', 'JJ'), ('aspect', 'NN'), ('of', 'IN'), ('the', 'DT'), ('introduction', 'NN'), ('of', 'IN'), ('algebraic', 'JJ'), ('ideas', 'NNS'), ('was', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('allowed', 'VBD'), ('mathematics', 'NNS'), ('to', 'TO'), ('be', 'VB'), ('applied', 'VBN'), ('to', 'TO'), ('itself', 'PRP'), ('in', 'IN'), ('a', 'DT'), ('way', 'NN'), ('which', 'WDT'), ('had', 'VBD'), ('not', 'RB'), ('happened', 'VBN'), ('before', 'IN'), ('.', '.')]

# %% [markdown]
# ### POS TAGGING FOR ARAB

# %%
#POS TAGGING FOR ARAB


post_tagArab = nltk.pos_tag(resul_word_token2)

print("#RESULT OF POST TAG: ",post_tagArab)
# Out:
# #RESULT OF POST TAG:  [('ربما', 'JJ'), ('كانت', 'NNP'), ('أحد', 'NNP'), ('أھم', 'NNP'), ('التطورات', 'NNP'), ('التي', 'NNP'), ('قامت', 'NNP'), ('بھا', 'NNP'), ('الریاضیات', 'NNP'), ('العربیة', 'NNP'), ('التي', 'NNP'), ('بدأت', 'NNP'), ('في', 'NNP'), ('ھذا', 'NNP'), ('الوقت', 'NNP'), ('بعمل', 'NNP'), ('الخوارزمي', 'NNP'), ('وھي', 'NNP'), ('بدایات', 'NNP'), ('الجبر،', 'NNP'), ('ومن', 'NNP'), ('المھم', 'NNP'), ('فھم', 'NNP'), ('كیف', 'NNP'), ('كانت', 'NNP'), ('ھذه', 'NNP'), ('الفكرة', 'NNP'), ('الجدیدة', 'NNP'), ('مھمة،', 'NNP'), ('فقد', 'NNP'), ('كانت', 'NNP'), ('خطوة', 'NNP'), ('ثوریة', 'NNP'), ('بعیدا', 'NNP'), ('عن', 'NNP'), ('المفھوم', 'NNP'), ('الیوناني', 'NNP'), ('للریاضیات', 'NNP'), ('التي', 'NNP'), ('ھي', 'NNP'), ('في', 'NNP'), ('جوھرھا', 'NNP'), ('ھندسة،', 'NNP'), ('الجبر', 'NNP'), ('كان', 'NNP'), ('نظریة', 'NNP'), ('موحدة', 'NNP'), ('تتیح', 'NNP'), ('الأعداد', 'NNP'), ('الكسریة', 'NNP'), ('والأعداد', 'NNP'), ('اللا', 'NNP'), ('كسریة،', 'NNP'), ('والمقادیر', 'NNP'), ('الھندسیة', 'NNP'), ('وغیرھا،', 'NNP'), ('أن', 'NNP'), ('تتعامل', 'NNP'), ('على', 'NNP'), ('أنھا', 'NNP'), ('أجسام', 'NNP'), ('جبریة،', 'NNP'), ('وأعطت', 'NNP'), ('الریاضیات', 'NNP'), ('ككل', 'NNP'), ('مسارا', 'NNP'), ('جدیدا', 'NNP'), ('للتطور', 'NNP'), ('بمفھوم', 'NNP'), ('أوسع', 'NNP'), ('بكثیر', 'NNP'), ('من', 'NNP'), ('الذي', 'NNP'), ('كان', 'NNP'), ('موجودا', 'NNP'), ('من', 'NNP'), ('قبل،', 'NNP'), ('وقدم', 'NNP'), ('وسیلة', 'NNP'), ('للتنمیة', 'NNP'), ('في', 'NNP'), ('ھذا', 'NNP'), ('الموضوع', 'NNP'), ('مستقبلا', 'NNP'), ('.', '.'), ('وجانب', 'VB'), ('آخر', 'JJ'), ('مھم', 'NNP'), ('لإدخال', 'NNP'), ('أفكار', 'NNP'), ('الجبر', 'NNP'), ('وھو', 'NNP'), ('أنھ', 'NNP'), ('سمح', 'NNP'), ('بتطبیق', 'NNP'), ('الریاضیات', 'NNP'), ('على', 'NNP'), ('نفسھا', 'NNP'), ('بطریقة', 'NNP'), ('لم', 'NNP'), ('تحدث', 'NNP'), ('من', 'NNP'), ('قبل', 'NN')]

# %% [markdown]
# ### POS TAGGING FOR PORTUGUESE

# %%
#POS TAGGING FOR PORTUGUESE


post_tagPort = nltk.pos_tag(resul_word_token3)

print("#RESULT OF POST TAG: ",post_tagPort)
# Out:
# #RESULT OF POST TAG:  [('Talvez', 'NNP'), ('um', 'JJ'), ('dos', 'NN'), ('avanços', 'NN'), ('mais', 'NN'), ('significativos', 'NN'), ('do', 'VBP'), ('árabe', 'VB'), ('tenha', 'VB'), ('começado', 'JJ'), ('nessa', 'JJ'), ('época', 'NN'), ('com', 'NN'), ('o', 'JJ'), ('trabalho', 'NN'), ('de', 'IN'), ('al-Khwarizmi', 'NN'), (',', ','), ('ou', 'JJ'), ('seja', 'NN'), (',', ','), ('o', 'FW'), ('início', 'FW'), ('da', 'NN'), ('álgebra', 'NN'), ('.', '.'), ('É', 'CC'), ('importante', 'JJ'), ('entender', 'NN'), ('o', 'NN'), ('quão', 'NN'), ('significativa', 'NN'), ('foi', 'NN'), ('essa', 'NN'), ('nova', 'JJ'), ('ideia', 'NN'), ('.', '.'), ('Foi', 'NNP'), ('um', 'JJ'), ('afastamento', 'NN'), ('revolucionário', 'NN'), ('do', 'VBP'), ('conceito', 'VB'), ('grego', 'NN'), ('de', 'IN'), ('matemática', 'FW'), (',', ','), ('que', 'FW'), ('era', 'NN'), ('essencialmente', 'NN'), ('geometria', 'NN'), ('.', '.'), ('A', 'DT'), ('álgebra', 'JJ'), ('era', 'NN'), ('uma', 'NN'), ('teoria', 'NN'), ('unificadora', 'JJ'), ('que', 'NN'), ('permitia', 'NN'), ('números', 'NNS'), (',', ','), ('números', 'NNS'), ('irracionais', 'VBP'), (',', ','), ('magnitudes', 'NNS'), ('geométricas', 'VBP'), (',', ','), ('etc.', 'FW'), (',', ','), ('todos', 'EX'), ('devem', 'FW'), ('ser', 'JJR'), ('tratados', 'NN'), ('como', 'NN'), ('``', '``'), ('objetos', 'JJ'), ('algébricos', 'NN'), ("''", "''"), ('.', '.'), ('Deu', 'NNP'), ('à', 'NNP'), ('matemática', 'NNP'), ('um', 'JJ'), ('caminho', 'NN'), ('de', 'IN'), ('desenvolvimento', 'FW'), ('totalmente', 'NN'), ('novo', 'NN'), (',', ','), ('muito', 'FW'), ('mais', 'FW'), ('amplo', 'FW'), ('em', 'FW'), ('conceito', 'NN'), ('do', 'VBP'), ('que', 'RB'), ('existia', 'VB'), ('antes', 'NNS'), (',', ','), ('e', 'VBP'), ('forneceu', 'JJ'), ('um', 'JJ'), ('veículo', 'NN'), ('para', 'NN'), ('o', 'NN'), ('desenvolvimento', 'NN'), ('futuro', 'NN'), ('do', 'VBP'), ('assunto', 'RB'), ('.', '.'), ('Outro', 'NNP'), ('aspecto', 'JJ'), ('importante', 'NN'), ('da', 'NN'), ('introdução', 'NN'), ('das', 'NN'), ('idéias', 'NN'), ('algébricas', 'NN'), ('foi', 'NN'), ('que', 'NN'), ('ela', 'VBP'), ('permitiu', 'NN'), ('que', 'NN'), ('a', 'DT'), ('matemática', 'NN'), ('fosse', 'NN'), ('aplicada', 'VBZ'), ('a', 'DT'), ('si', 'JJ'), ('mesma', 'NN'), ('de', 'IN'), ('uma', 'JJ'), ('forma', 'JJ'), ('que', 'NN'), ('não', 'JJ'), ('havia', 'NN'), ('acontecido', 'NN'), ('antes', 'NNS'), ('.', '.')]

# %% [markdown]
# ### CHUNK FOR ANGLISH

# %%
#CHUNK FOR ANGLISH

result_Chunk_Eng = nltk.chunk.ne_chunk(post_tagEng)

#PRINT CHUNK OF ENGLISH

print(result_Chunk_Eng)
# Out:
# (S
#   Perhaps/RB
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   significant/JJ
#   advances/NNS
#   made/VBN
#   by/IN
#   (PERSON Arabic/NNP)
#   mathematics/NNS
#   began/VBD
#   at/IN
#   this/DT
#   time/NN
#   with/IN
#   the/DT
#   work/NN
#   of/IN
#   al-Khwarizmi/JJ
#   ,/,
#   namely/RB
#   the/DT
#   beginnings/NNS
#   of/IN
#   algebra/NN
#   ./.
#   It/PRP
#   is/VBZ
#   important/JJ
#   to/TO
#   understand/VB
#   just/RB
#   how/WRB
#   significant/JJ
#   this/DT
#   new/JJ
#   idea/NN
#   was/VBD
#   ./.
#   It/PRP
#   was/VBD
#   a/DT
#   revolutionary/JJ
#   move/NN
#   away/RB
#   from/IN
#   the/DT
#   (GPE Greek/NNP)
#   concept/NN
#   of/IN
#   mathematics/NNS
#   which/WDT
#   was/VBD
#   essentially/RB
#   geometry/JJ
#   ./.
#   (PERSON Algebra/NNP)
#   was/VBD
#   a/DT
#   unifying/JJ
#   theory/NN
#   which/WDT
#   allowed/VBD
#   rational/JJ
#   numbers/NNS
#   ,/,
#   irrational/JJ
#   numbers/NNS
#   ,/,
#   geometrical/JJ
#   magnitudes/NNS
#   ,/,
#   etc./NN
#   ,/,
#   to/TO
#   all/DT
#   be/VB
#   treated/VBN
#   as/IN
#   ``/``
#   algebraic/JJ
#   objects/NNS
#   ''/''
#   ./.
#   It/PRP
#   gave/VBD
#   mathematics/NNS
#   a/DT
#   whole/JJ
#   new/JJ
#   development/NN
#   path/NN
#   so/RB
#   much/JJ
#   broader/JJR
#   in/IN
#   concept/NN
#   to/TO
#   that/DT
#   which/WDT
#   had/VBD
#   existed/VBN
#   before/IN
#   ,/,
#   and/CC
#   provided/VBD
#   a/DT
#   vehicle/NN
#   for/IN
#   future/JJ
#   development/NN
#   of/IN
#   the/DT
#   subject/NN
#   ./.
#   Another/DT
#   important/JJ
#   aspect/NN
#   of/IN
#   the/DT
#   introduction/NN
#   of/IN
#   algebraic/JJ
#   ideas/NNS
#   was/VBD
#   that/IN
#   it/PRP
#   allowed/VBD
#   mathematics/NNS
#   to/TO
#   be/VB
#   applied/VBN
#   to/TO
#   itself/PRP
#   in/IN
#   a/DT
#   way/NN
#   which/WDT
#   had/VBD
#   not/RB
#   happened/VBN
#   before/IN
#   ./.)

# %% [markdown]
# ### CHUNK FOR ARAB

# %%
#CHUNK FOR ARAB

result_Chunk_Arab = nltk.chunk.ne_chunk(post_tagArab)

#PRINT CHUNK OF ENGLISH

print(result_Chunk_Arab)
# Out:
# (S
#   (ORGANIZATION ربما/JJ)
#   (ORGANIZATION كانت/NNP)
#   أحد/NNP
#   أھم/NNP
#   التطورات/NNP
#   التي/NNP
#   قامت/NNP
#   بھا/NNP
#   الریاضیات/NNP
#   العربیة/NNP
#   التي/NNP
#   بدأت/NNP
#   في/NNP
#   ھذا/NNP
#   الوقت/NNP
#   بعمل/NNP
#   الخوارزمي/NNP
#   وھي/NNP
#   بدایات/NNP
#   الجبر،/NNP
#   ومن/NNP
#   المھم/NNP
#   فھم/NNP
#   كیف/NNP
#   كانت/NNP
#   ھذه/NNP
#   الفكرة/NNP
#   الجدیدة/NNP
#   مھمة،/NNP
#   فقد/NNP
#   كانت/NNP
#   خطوة/NNP
#   ثوریة/NNP
#   بعیدا/NNP
#   عن/NNP
#   المفھوم/NNP
#   الیوناني/NNP
#   للریاضیات/NNP
#   التي/NNP
#   ھي/NNP
#   في/NNP
#   جوھرھا/NNP
#   ھندسة،/NNP
#   الجبر/NNP
#   كان/NNP
#   نظریة/NNP
#   موحدة/NNP
#   تتیح/NNP
#   الأعداد/NNP
#   الكسریة/NNP
#   والأعداد/NNP
#   اللا/NNP
#   كسریة،/NNP
#   والمقادیر/NNP
#   الھندسیة/NNP
#   وغیرھا،/NNP
#   أن/NNP
#   تتعامل/NNP
#   على/NNP
#   أنھا/NNP
#   أجسام/NNP
#   جبریة،/NNP
#   وأعطت/NNP
#   الریاضیات/NNP
#   ككل/NNP
#   مسارا/NNP
#   جدیدا/NNP
#   للتطور/NNP
#   بمفھوم/NNP
#   أوسع/NNP
#   بكثیر/NNP
#   من/NNP
#   الذي/NNP
#   كان/NNP
#   موجودا/NNP
#   من/NNP
#   قبل،/NNP
#   وقدم/NNP
#   وسیلة/NNP
#   للتنمیة/NNP
#   في/NNP
#   ھذا/NNP
#   الموضوع/NNP
#   مستقبلا/NNP
#   ./.
#   وجانب/VB
#   (ORGANIZATION آخر/JJ)
#   (ORGANIZATION مھم/NNP)
#   لإدخال/NNP
#   أفكار/NNP
#   الجبر/NNP
#   وھو/NNP
#   أنھ/NNP
#   سمح/NNP
#   بتطبیق/NNP
#   الریاضیات/NNP
#   على/NNP
#   نفسھا/NNP
#   بطریقة/NNP
#   لم/NNP
#   تحدث/NNP
#   من/NNP
#   قبل/NN)

# %% [markdown]
# ### CHUNK FOR PORTUGUESE

# %%
#CHUNK FOR 

result_Chunk_Port = nltk.chunk.ne_chunk(post_tagPort)

#PRINT CHUNK OF ENGLISH

print(result_Chunk_Port)
# Out:
# (S
#   (GPE Talvez/NNP)
#   um/JJ
#   dos/NN
#   avanços/NN
#   mais/NN
#   significativos/NN
#   do/VBP
#   árabe/VB
#   tenha/VB
#   começado/JJ
#   nessa/JJ
#   época/NN
#   com/NN
#   o/JJ
#   trabalho/NN
#   de/IN
#   al-Khwarizmi/NN
#   ,/,
#   ou/JJ
#   seja/NN
#   ,/,
#   o/FW
#   início/FW
#   da/NN
#   álgebra/NN
#   ./.
#   É/CC
#   importante/JJ
#   entender/NN
#   o/NN
#   quão/NN
#   significativa/NN
#   foi/NN
#   essa/NN
#   nova/JJ
#   ideia/NN
#   ./.
#   Foi/NNP
#   um/JJ
#   afastamento/NN
#   revolucionário/NN
#   do/VBP
#   conceito/VB
#   grego/NN
#   de/IN
#   matemática/FW
#   ,/,
#   que/FW
#   era/NN
#   essencialmente/NN
#   geometria/NN
#   ./.
#   A/DT
#   álgebra/JJ
#   era/NN
#   uma/NN
#   teoria/NN
#   unificadora/JJ
#   que/NN
#   permitia/NN
#   números/NNS
#   ,/,
#   números/NNS
#   irracionais/VBP
#   ,/,
#   magnitudes/NNS
#   geométricas/VBP
#   ,/,
#   etc./FW
#   ,/,
#   todos/EX
#   devem/FW
#   ser/JJR
#   tratados/NN
#   como/NN
#   ``/``
#   objetos/JJ
#   algébricos/NN
#   ''/''
#   ./.
#   (PERSON Deu/NNP)
#   à/NNP
#   matemática/NNP
#   um/JJ
#   caminho/NN
#   de/IN
#   desenvolvimento/FW
#   totalmente/NN
#   novo/NN
#   ,/,
#   muito/FW
#   mais/FW
#   amplo/FW
#   em/FW
#   conceito/NN
#   do/VBP
#   que/RB
#   existia/VB
#   antes/NNS
#   ,/,
#   e/VBP
#   forneceu/JJ
#   um/JJ
#   veículo/NN
#   para/NN
#   o/NN
#   desenvolvimento/NN
#   futuro/NN
#   do/VBP
#   assunto/RB
#   ./.
#   Outro/NNP
#   aspecto/JJ
#   importante/NN
#   da/NN
#   introdução/NN
#   das/NN
#   idéias/NN
#   algébricas/NN
#   foi/NN
#   que/NN
#   ela/VBP
#   permitiu/NN
#   que/NN
#   a/DT
#   matemática/NN
#   fosse/NN
#   aplicada/VBZ
#   a/DT
#   si/JJ
#   mesma/NN
#   de/IN
#   uma/JJ
#   forma/JJ
#   que/NN
#   não/JJ
#   havia/NN
#   acontecido/NN
#   antes/NNS
#   ./.)

# %% [markdown]
# # Stemming

# %%
#IMPORT LIBRARY STEMMING

from nltk.stem import PorterStemmer

from nltk.tokenize import word_tokenize

English_text=("""
            Perhaps one of the most significant advances made by Arabic mathematics began at this time 
            with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to 
            understand just how significant this new idea was. It was a revolutionary move away 
            from the Greek concept of mathematics which was essentially geometry. Algebra was a 
            unifying theory which allowed rational numbers, irrational numbers, geometrical 
            magnitudes,etc., to all be treated as "algebraic objects". It gave mathematics a whole new 
            development path so much broader in concept to that which had existed before, and provided a
            vehicle for future development of the subject. Another important aspect of the introduction 
            of algebraic ideas was that it allowed mathematics to be applied to itself in a way which 
            had not happened before.
    """)

words = word_tokenize(English_text)
ps = PorterStemmer()
for w in words:
	rootWord=ps.stem(w)
	print("",rootWord)
# Out:
#  perhap
#  one
#  of
#  the
#  most
#  signific
#  advanc
#  made
#  by
#  arab
#  mathemat
#  began
#  at
#  thi
#  time
#  with
#  the
#  work
#  of
#  al-khwarizmi
#  ,
#  name
#  the
#  begin
#  of
#  algebra
#  .
#  it
#  is
#  import
#  to
#  understand
#  just
#  how
#  signific
#  thi
#  new
#  idea
#  wa
#  .
#  it
#  wa
#  a
#  revolutionari
#  move
#  away
#  from
#  the
#  greek
#  concept
#  of
#  mathemat
#  which
#  wa
#  essenti
#  geometri
#  .
#  algebra
#  wa
#  a
#  unifi
#  theori
#  which
#  allow
#  ration
#  number
#  ,
#  irrat
#  number
#  ,
#  geometr
#  magnitud
#  ,
#  etc.
#  ,
#  to
#  all
#  be
#  treat
#  as
#  ``
#  algebra
#  object
#  ''
#  .
#  it
#  gave
#  mathemat
#  a
#  whole
#  new
#  develop
#  path
#  so
#  much
#  broader
#  in
#  concept
#  to
#  that
#  which
#  had
#  exist
#  befor
#  ,
#  and
#  provid
#  a
#  vehicl
#  for
#  futur
#  develop
#  of
#  the
#  subject
#  .
#  anoth
#  import
#  aspect
#  of
#  the
#  introduct
#  of
#  algebra
#  idea
#  wa
#  that
#  it
#  allow
#  mathemat
#  to
#  be
#  appli
#  to
#  itself
#  in
#  a
#  way
#  which
#  had
#  not
#  happen
#  befor
#  .

# %% [markdown]
# # Lemmatization

# %%
#IMPORT OF LIBRARY

import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize

#nltk.download('wordnet')  

wordnet_lemmatizer = WordNetLemmatizer()

# %%
    English_text3 = ("""
    
            Perhaps one of the most significant advances made by Arabic mathematics began at this time 
            with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to 
            understand just how significant this new idea was. It was a revolutionary move away 
            from the Greek concept of mathematics which was essentially geometry. Algebra was a 
            unifying theory which allowed rational numbers, irrational numbers, geometrical 
            magnitudes,etc., to all be treated as "algebraic objects". It gave mathematics a whole new 
            development path so much broader in concept to that which had existed before, and provided a
            vehicle for future development of the subject. Another important aspect of the introduction 
            of algebraic ideas was that it allowed mathematics to be applied to itself in a way which 
            had not happened before.
    
    """ )
    
    
    token = nltk.word_tokenize(English_text3)
    
    print("THIS IS THE LIST OF LAMMATIZATION : ")
    for w in token:
        
            #PRINT LAMMATIZATION

            print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# THIS IS THE LIST OF LAMMATIZATION :
# Lemma for Perhaps is Perhaps
# Lemma for one is one
# Lemma for of is of
# Lemma for the is the
# Lemma for most is most
# Lemma for significant is significant
# Lemma for advances is advance
# Lemma for made is made
# Lemma for by is by
# Lemma for Arabic is Arabic
# Lemma for mathematics is mathematics
# Lemma for began is began
# Lemma for at is at
# Lemma for this is this
# Lemma for time is time
# Lemma for with is with
# Lemma for the is the
# Lemma for work is work
# Lemma for of is of
# Lemma for al-Khwarizmi is al-Khwarizmi
# Lemma for , is ,
# Lemma for namely is namely
# Lemma for the is the
# Lemma for beginnings is beginning
# Lemma for of is of
# Lemma for algebra is algebra
# Lemma for . is .
# Lemma for It is It
# Lemma for is is is
# Lemma for important is important
# Lemma for to is to
# Lemma for understand is understand
# Lemma for just is just
# Lemma for how is how
# Lemma for significant is significant
# Lemma for this is this
# Lemma for new is new
# Lemma for idea is idea
# Lemma for was is wa
# Lemma for . is .
# Lemma for It is It
# Lemma for was is wa
# Lemma for a is a
# Lemma for revolutionary is revolutionary
# Lemma for move is move
# Lemma for away is away
# Lemma for from is from
# Lemma for the is the
# Lemma for Greek is Greek
# Lemma for concept is concept
# Lemma for of is of
# Lemma for mathematics is mathematics
# Lemma for which is which
# Lemma for was is wa
# Lemma for essentially is essentially
# Lemma for geometry is geometry
# Lemma for . is .
# Lemma for Algebra is Algebra
# Lemma for was is wa
# Lemma for a is a
# Lemma for unifying is unifying
# Lemma for theory is theory
# Lemma for which is which
# Lemma for allowed is allowed
# Lemma for rational is rational
# Lemma for numbers is number
# Lemma for , is ,
# Lemma for irrational is irrational
# Lemma for numbers is number
# Lemma for , is ,
# Lemma for geometrical is geometrical
# Lemma for magnitudes is magnitude
# Lemma for , is ,
# Lemma for etc. is etc.
# Lemma for , is ,
# Lemma for to is to
# Lemma for all is all
# Lemma for be is be
# Lemma for treated is treated
# Lemma for as is a
# Lemma for `` is ``
# Lemma for algebraic is algebraic
# Lemma for objects is object
# Lemma for '' is ''
# Lemma for . is .
# Lemma for It is It
# Lemma for gave is gave
# Lemma for mathematics is mathematics
# Lemma for a is a
# Lemma for whole is whole
# Lemma for new is new
# Lemma for development is development
# Lemma for path is path
# Lemma for so is so
# Lemma for much is much
# Lemma for broader is broader
# Lemma for in is in
# Lemma for concept is concept
# Lemma for to is to
# Lemma for that is that
# Lemma for which is which
# Lemma for had is had
# Lemma for existed is existed
# Lemma for before is before
# Lemma for , is ,
# Lemma for and is and
# Lemma for provided is provided
# Lemma for a is a
# Lemma for vehicle is vehicle
# Lemma for for is for
# Lemma for future is future
# Lemma for development is development
# Lemma for of is of
# Lemma for the is the
# Lemma for subject is subject
# Lemma for . is .
# Lemma for Another is Another
# Lemma for important is important
# Lemma for aspect is aspect
# Lemma for of is of
# Lemma for the is the
# Lemma for introduction is introduction
# Lemma for of is of
# Lemma for algebraic is algebraic
# Lemma for ideas is idea
# Lemma for was is wa
# Lemma for that is that
# Lemma for it is it
# Lemma for allowed is allowed
# Lemma for mathematics is mathematics
# Lemma for to is to
# Lemma for be is be
# Lemma for applied is applied
# Lemma for to is to
# Lemma for itself is itself
# Lemma for in is in
# Lemma for a is a
# Lemma for way is way
# Lemma for which is which
# Lemma for had is had
# Lemma for not is not
# Lemma for happened is happened
# Lemma for before is before
# Lemma for . is .
